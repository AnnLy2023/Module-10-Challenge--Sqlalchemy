# %% [markdown]
# # PART 1: Analyze and Explore the Climate Data

# %%
#Dependencies
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, text

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Utilize SQLAlchemy create engine function to connect to SQlite database
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# INSPECT
inspector_gadget = inspect(engine)

# get all tables
table_names = inspector_gadget.get_table_names()
for table in table_names:
    print(table)
    
    # get columns for table
    for column in inspector_gadget.get_columns(table):
        print(column)
        
    print()
# Out:
# measurement
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'station', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'date', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'prcp', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'tobs', 'type': FLOAT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
#
# station
# {'name': 'id', 'type': INTEGER(), 'nullable': False, 'default': None, 'autoincrement': 'auto', 'primary_key': 1}
# {'name': 'station', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# {'name': 'name', 'type': TEXT(), 'nullable': True, 'default': None, 'autoincrement': 'auto', 'primary_key': 0}
# ...

# %%
#Create a query that finds the most recent date in the data set (8/23/2017)

query = text("""
                SELECT
                    date,
                    prcp
                FROM
                    measurement
                group by
                    date
                order by
                    date desc
                limit 3000
            """)

pd.read_sql(query, engine)
# Out:
#             date  prcp
# 0     2017-08-23  0.00
# 1     2017-08-22  0.00
# 2     2017-08-21  0.00
# 3     2017-08-20  0.00
# 4     2017-08-19  0.00
# ...          ...   ...
# 2787  2010-01-05  0.00
# 2788  2010-01-04  0.00
# 2789  2010-01-03  0.00
# 2790  2010-01-02  0.00
# 2791  2010-01-01  0.08
#
# [2792 rows x 2 columns]

# %%
#Create a query that collects only the date and precipitation for the last year of data without passing the date as a variable
#Save the query results to a Pandas DataFrame to create date and precipitation columns

query = text("""
                SELECT
                    date,
                    station,
                    prcp
                FROM
                    measurement
                WHERE
                    date >= '2016-08-23';
               
            """)

df = pd.read_sql(query, engine)
df.head()
# Out:
#          date      station  prcp
# 0  2016-08-23  USC00519397  0.00
# 1  2016-08-24  USC00519397  0.08
# 2  2016-08-25  USC00519397  0.08
# 3  2016-08-26  USC00519397  0.00
# 4  2016-08-27  USC00519397  0.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     2230 non-null   object
#  1   station  2230 non-null   object
#  2   prcp     2021 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 52.4+ KB

# %%
#convert Data type for "date"

df["date"] = pd.to_datetime(df["date"])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2230 entries, 0 to 2229
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     2230 non-null   datetime64[ns]
#  1   station  2230 non-null   object
#  2   prcp     2021 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 52.4+ KB

# %%
#Sort the dataframe by date


df1 = df.dropna().sort_values(by="date", ascending=True).reset_index(drop=True)
df1.head(10)
# Out:
#         date      station  prcp
# 0 2016-08-23  USC00519397  0.00
# 1 2016-08-23  USC00519523  0.02
# 2 2016-08-23  USC00514830  0.05
# 3 2016-08-23  USC00516128  0.70
# 4 2016-08-23  USC00513117  0.15
# 5 2016-08-23  USC00519281  1.79
# 6 2016-08-24  USC00519523  1.22
# 7 2016-08-24  USC00519397  0.08
# 8 2016-08-24  USC00519281  2.15
# 9 2016-08-24  USC00513117  2.15

# %%
plt.title("Amount of Precipitation in Inches from 8-23-2016 to 8-23-2017")
plt.xlabel("Date")
plt.ylabel("Amount of Precipitation in Inches")
plt.plot(df1.date, df1.prcp, color="orange")
plt.show()

# %%
#Use Pandas to print the summary statistics for the precipitation date
df1.describe()
# Out:
#               prcp
# count  2021.000000
# mean      0.177279
# std       0.461190
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %%
df.groupby("station").prcp.describe()
# Out:
#              count      mean       std  min   25%   50%    75%   max
# station
# USC00513117  343.0  0.141429  0.341245  0.0  0.00  0.03  0.120  2.90
# USC00514830  265.0  0.125434  0.316290  0.0  0.00  0.02  0.120  2.39
# USC00516128  328.0  0.450640  0.717174  0.0  0.01  0.19  0.610  6.70
# USC00517948   60.0  0.076500  0.317857  0.0  0.00  0.00  0.025  2.40
# USC00519281  352.0  0.198949  0.419182  0.0  0.00  0.06  0.190  2.98
# USC00519397  359.0  0.044819  0.188810  0.0  0.00  0.00  0.020  2.62
# USC00519523  314.0  0.121051  0.509002  0.0  0.00  0.00  0.060  6.25

# %% [markdown]
# # Station Analysis

# %%
#Design a query that correctly finds the number of stations in the dataset (9)
df.station.value_counts()
# Out:
# USC00519397    361
# USC00519281    352
# USC00516128    349
# USC00513117    343
# USC00519523    337
# USC00514830    305
# USC00517948    183
# Name: station, dtype: int64

# %%
#Design a query that correctly lists the stations and observation counts in descending order and finds the most active station (USC00519281)

query = text("""
                SELECT
                    station,
                    count(*) as num_obs
                FROM
                    measurement
                group by
                    station
                order by
                    num_obs desc;
            """)

pd.read_sql(query, engine)
# Out:
#        station  num_obs
# 0  USC00519281     2772
# 1  USC00519397     2724
# 2  USC00513117     2709
# 3  USC00519523     2669
# 4  USC00516128     2612
# 5  USC00514830     2202
# 6  USC00511918     1979
# 7  USC00517948     1372
# 8  USC00518838      511

# %%
#Design a query that correctly finds the min, max, and avg temp for the most active station (USC00519281)
query = text("""
                SELECT
                    station,
                    min(prcp),
                    avg(prcp),
                    max(prcp)
                FROM
                    measurement
                where
                    station = 'USC00519281';
            """)

pd.read_sql(query, engine)
# Out:
#        station  min(prcp)  avg(prcp)  max(prcp)
# 0  USC00519281        0.0   0.212352       9.64

# %%
#Design a query to get the previous 12 months of temperature observation (TOBS) data that filters by the station that has the greatest number of observations

query = text("""
                SELECT
                    date,
                    station,
                    tobs
                FROM
                    measurement
                WHERE
                    date >= '2016-08-23'
                    and station = 'USC00519281'
            """)

df3 = pd.read_sql(query, engine)
df3.head()
# Out:
#          date      station  tobs
# 0  2016-08-23  USC00519281  77.0
# 1  2016-08-24  USC00519281  77.0
# 2  2016-08-25  USC00519281  80.0
# 3  2016-08-26  USC00519281  80.0
# 4  2016-08-27  USC00519281  75.0

# %%
plt.hist(df3.tobs, color="green", bins=12)
plt.title("Temperature Observation from 8-23-2016 to 8-23-2017 for station USC00519281")
plt.ylabel("Frequency")
plt.xlabel("Temperature")
plt.grid()
plt.show()
